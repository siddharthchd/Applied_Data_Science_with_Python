# %%
# %matplotlib notebook

# %%
import matplotlib as mpl
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt
plt.plot?

# %%
# since default is line style, single point will do nothing
plt.plot(3, 2)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
plt.plot(3, 2, '*')

# %%
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure

fig = Figure()
canvas = FigureCanvasAgg(fig)
ax = fig.add_subplot(111)
ax.plot(3, 2, '.')
canvas.print_png('test.png')

# %%
# %%html
# <img src = 'test.png'/>
# Out:
# <img src = 'test.png'/>

# %%
plt.figure()
plt.plot(3, 2, 'o')
ax = plt.gca()
ax.axis([0, 6, 0, 10])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# [0, 6, 0, 10]

# %%
plt.figure()
plt.plot(1.5, 1.5, 'o')
plt.plot(2, 2, 'o')
plt.plot(2.5, 2.5, 'o')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
ax = plt.gca()
ax.get_children()
# Out:
# [<matplotlib.lines.Line2D at 0x1d7e45943c8>,
#  <matplotlib.lines.Line2D at 0x1d7e45b9848>,
#  <matplotlib.lines.Line2D at 0x1d7e45bd388>,
#  <matplotlib.spines.Spine at 0x1d7e45abcc8>,
#  <matplotlib.spines.Spine at 0x1d7e45ab808>,
#  <matplotlib.spines.Spine at 0x1d7e45ab7c8>,
#  <matplotlib.spines.Spine at 0x1d7e45904c8>,
#  <matplotlib.axis.XAxis at 0x1d7e45aba48>,
#  <matplotlib.axis.YAxis at 0x1d7e45b1c48>,
#  Text(0.5, 1, ''),
#  Text(0.0, 1, ''),
#  Text(1.0, 1, ''),
#  <matplotlib.patches.Rectangle at 0x1d7e45b9608>]
